# %%
# %matplotlib inline
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from copy import copy
from sklearn.ensemble import RandomForestRegressor
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import itertools
from sklearn.svm import SVR
from sklearn.decomposition import PCA
import matplotlib.patches as mpatches

l=[1,2,3,4,1,2,4,3,1,2]
a=pd.Series(l)

# %%
l=np.array(l)
l=l+100
a2=pd.Series(l)

palettle_seasons=np.array(sns.color_palette("hls",4))
patches_season=[mpatches.Patch(color=palettle_seasons[i-1]) for i in range(1,5)]
plt.plot(a,c=palettle_seasons[3])
plt.plot(a2,c=palettle_seasons[2])
