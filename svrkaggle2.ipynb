# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from copy import copy
from sklearn.ensemble import RandomForestRegressor
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import itertools
from sklearn.svm import SVR
from sklearn.decomposition import PCA

dateparse=lambda x:pd.datetime.strptime(x,'%Y-%m-%d %H:%M:%S')
train=pd.read_csv('train.csv',parse_dates=['datetime'],date_parser=dateparse)
test=pd.read_csv('test.csv',parse_dates=['datetime'],date_parser=dateparse)

#test['windspeed']=np.log(test['windspeed']+1)
#train['windspeed']=np.log(train['windspeed']+1)
print 'train.shape is ',train.shape,' and test.shape is ',test.shape


def extractFeaturesTrain(data):
    #print 'data is ',data
    data['Hour']=data.datetime.dt.hour
    data['DayOfWeek']=data.datetime.dt.dayofweek
    labels=data['count']
    train_years=data.datetime.dt.year
    train_months=data.datetime.dt.month
    data=data.drop(['datetime','count','casual','registered'], axis = 1)
    
    return np.array(data),np.array(labels),np.array(train_years),np.array(train_months),(data.columns.values)

def extractFeaturesTest(data):
    #print 'data is \n',data
    data['Hour']=data.datetime.dt.hour
    data['DayOfWeek']=data.datetime.dt.dayofweek
    test_years=data.datetime.dt.year
    test_months=data.datetime.dt.month
    data=data.drop(['datetime'], axis = 1)
    return np.array(data),np.array(test_years),np.array(test_months)
    
train2=copy(train)
test2=copy(test)
test=np.array(test)
#print 'train2 is ',train2
traind,labelsTrain,train_years,train_months,headers=extractFeaturesTrain(train2)
testd,test_years,test_months=extractFeaturesTest(test2)

cov1=np.cov(traind.T)

eigs=np.linalg.eigvals(cov1)
print 'eigs are \n',eigs
for i in range(traind.shape[1]):
    print 'Feature : ',headers[i],' : eigenvalue : ',eigs[i]
    

print 'traind.shape is ',traind.shape,' and testd.shape is ',testd.shape
# Out:
# train.shape is  (10886, 12)  and test.shape is  (6493, 9)
# eigs are
# [  3.83414009e+02   1.32554143e+02   5.88191023e+01   4.19067213e+01
#    4.11464615e+00   1.10100354e+00   9.35169847e-01   3.21037576e-01
#    1.15903111e-01   1.68009324e-02]
# Feature :  season  : eigenvalue :  383.414009296
# Feature :  holiday  : eigenvalue :  132.554143152
# Feature :  workingday  : eigenvalue :  58.8191022927
# Feature :  weather  : eigenvalue :  41.9067212646
# Feature :  temp  : eigenvalue :  4.11464614996
# Feature :  atemp  : eigenvalue :  1.10100353588
# Feature :  humidity  : eigenvalue :  0.935169847006
# Feature :  windspeed  : eigenvalue :  0.321037576143
# Feature :  Hour  : eigenvalue :  0.115903111124
# Feature :  DayOfWeek  : eigenvalue :  0.0168009324301
# traind.shape is  (10886, 10)  and testd.shape is  (6493, 10)

# %%
enc=OneHotEncoder(categorical_features=[0],sparse=False)
traind2=enc.fit_transform(traind)
print traind2.shape
testd2=enc.fit_transform(testd)
print testd2.shape
ones1=np.ones((traind.shape[0],1))
ones2=np.ones((testd.shape[0],1))
traind2=copy(np.hstack((traind2,ones1)))
testd2=copy(np.hstack((testd2,ones2)))
print traind2.shape
print testd2.shape
# Out:
# (10886, 24)
# (6493, 24)
# (10886, 25)
# (6493, 25)

# %%
train=np.array(train)
#


def getSplits(years,months):
    locsTrain=[]
    locsTest=[]
    print 'in getSplits ,train is \n',train
    for i in range(0,train.shape[0]):
            if (train[i,0].year==years[0] or train[i,0].year==years[1]) and (train[i,0].month in months):
                locsTest.append(i)
            else:
                locsTrain.append(i) 
    
    return locsTrain,locsTest

def getCustomLocsTest(year,month,data):
    locs=[]
    for i in range(0,data.shape[0]):
        if data[i][0].year==year and data[i][0].month==month:
            locs.append(i)
    return locs
    
def TrainFucntion(x,y,xtest,ytest):
    weights=np.random.rand(1,x.shape[1])
    Cs=[0.01,0.1,1,10,100,1000]
    epsilons=np.arange(0,2,0.2)
    losses=[]
    parameters=list(itertools.product(Cs,epsilons))
    plotx=[]
    ploty=[]
    for p in parameters:
        plotx.append(p[0])
        ploty.append(p[1])

        svr=SVR(C=p[0],epsilon=p[1],kernel='poly',degree=5)
        svr.fit(x,y)
        ypred=svr.predict(xtest)
        #print 'ypred is \n',ypred
        loss=findLoss(ytest,ypred)
        losses.append(loss)
        print 'Loss with C=',p[0],' and epsilon= ',p[1],' is ',loss
    
    fig = plt.figure()
    ax=fig.add_subplot(111,projection='3d')
    ax.scatter(plotx,ploty,accuracies)
    plt.title('Loss of SVR with C and epsilon')
    plt.xtitle('C')
    plt.ytitle('epsilon')
    plt.show()
    

def Predict(weights,test):
    
    return np.dot(test,weights.T)

def findLoss(gold,predicted):
    loss=0
    
    #print 'predicted is ',predicted
    for i in range(gold.shape[0]):
        loss+=(np.log(predicted[i]+1) -np.log(gold[i]+1))**2
    
    loss=loss/gold.shape[0]
    return np.sqrt(loss)

def crossValidate():
        months=[10]
        locsTrain,locsTest=getSplits([2011,2012],months)
        
        testSubset=traind2[locsTest]
        testSubset2=train[locsTest]
        testLabels=labelsTrain[locsTest]
        #rf3=RandomForestRegressor(20) 
        
        trainSubset=traind2[locsTrain]
        trainSubset2=train[locsTrain]
        trainLabels=labelsTrain[locsTrain]
        
        for i in [2011,2012]:
            for j in months:
                testLocs=getCustomLocsTest(i,j,testSubset2)
                testSubset3=testSubset2[testLocs]
                testSubset4=testSubset[testLocs]
                testLabels4=testLabels[testLocs]
                
                trainLocs2=np.where(trainSubset2[:,0]<=min(testSubset3[:,0]))
                
                trainSubset3=trainSubset[trainLocs2]
                trainLabels3=trainLabels[trainLocs2]
                x1=trainSubset2[trainLocs2]
                x2=testSubset2[testLocs]
                
                print 'trainSubset min is  ', min(x1[:,0]),' and max is ',max(x1[:,0])
                print 'testSubset  min is  ', min(x2[:,0]),' and max is ',max(x2[:,0])
                for i in range(trainSubset3.shape[1]):
                    if max(trainSubset3[:,i])!=0:
                        trainSubset3[:,i]=trainSubset3[:,i]/max(trainSubset3[:,i])
                for i in range(testSubset4.shape[1]):
                    if max(testSubset4[:,i])!=0:
                        testSubset4[:,i]=testSubset4[:,i]/max(testSubset4[:,i])
                #rf3.fit(trainSubset3,trainLabels3)change here to program new function to train
                TrainFucntion(trainSubset3,trainLabels3,testSubset4,testLabels4)
                
                
                
crossValidate()
# Out:
# in getSplits ,train is
# [[Timestamp('2011-01-01 00:00:00') 1 0 ..., 16 0 5]
#  [Timestamp('2011-01-01 01:00:00') 1 0 ..., 40 1 5]
#  [Timestamp('2011-01-01 02:00:00') 1 0 ..., 32 2 5]
#  ...,
#  [Timestamp('2012-12-19 21:00:00') 4 0 ..., 168 21 2]
#  [Timestamp('2012-12-19 22:00:00') 4 0 ..., 129 22 2]
#  [Timestamp('2012-12-19 23:00:00') 4 0 ..., 88 23 2]]
# trainSubset min is   2011-01-01 00:00:00  and max is  2011-09-19 23:00:00
# testSubset  min is   2011-10-01 00:00:00  and max is  2011-10-19 23:00:00
# Loss with C= 0.01  and epsilon=  0.0  is  1.31416025164
# Loss with C= 0.01  and epsilon=  0.2  is  1.31407489449
# Loss with C= 0.01  and epsilon=  0.4  is  1.31399214122
# Loss with C= 0.01  and epsilon=  0.6  is  1.31399214063
# Loss with C= 0.01  and epsilon=  0.8  is  1.31407489389
# Loss with C= 0.01  and epsilon=  1.0  is  1.31416025157
# Loss with C= 0.01  and epsilon=  1.2  is  1.31407489381
# Loss with C= 0.01  and epsilon=  1.4  is  1.31399214055
# Loss with C= 0.01  and epsilon=  1.6  is  1.31399213951
# Loss with C= 0.01  and epsilon=  1.8  is  1.31407489274
# Loss with C= 0.1  and epsilon=  0.0  is  1.31415999842
# Loss with C= 0.1  and epsilon=  0.2  is  1.31407465722
# Loss with C= 0.1  and epsilon=  0.4  is  1.31399190313
# Loss with C= 0.1  and epsilon=  0.6  is  1.31399189729
# Loss with C= 0.1  and epsilon=  0.8  is  1.3140746512
# Loss with C= 0.1  and epsilon=  1.0  is  1.31415999771
# Loss with C= 0.1  and epsilon=  1.2  is  1.31407465037
# Loss with C= 0.1  and epsilon=  1.4  is  1.31399189649
# Loss with C= 0.1  and epsilon=  1.6  is  1.31399188608
# Loss with C= 0.1  and epsilon=  1.8  is  1.31407463963
# Loss with C= 1  and epsilon=  0.0  is  1.3141574662
# Loss with C= 1  and epsilon=  0.2  is  1.31407228454
# Loss with C= 1  and epsilon=  0.4  is  1.31398952224
# Loss with C= 1  and epsilon=  0.6  is  1.31398946384
# Loss with C= 1  and epsilon=  0.8  is  1.31407222429
# Loss with C= 1  and epsilon=  1.0  is  1.31415745911
# Loss with C= 1  and epsilon=  1.2  is  1.31407221601
# Loss with C= 1  and epsilon=  1.4  is  1.31398945584
# Loss with C= 1  and epsilon=  1.6  is  1.31398935173
# Loss with C= 1  and epsilon=  1.8  is  1.31407210859
# Loss with C= 10  and epsilon=  0.0  is  1.31413214356
# Loss with C= 10  and epsilon=  0.2  is  1.31404855839
# Loss with C= 10  and epsilon=  0.4  is  1.31396571416
# Loss with C= 10  and epsilon=  0.6  is  1.31396513394
# Loss with C= 10  and epsilon=  0.8  is  1.31404795972
# Loss with C= 10  and epsilon=  1.0  is  1.31413207262
# Loss with C= 10  and epsilon=  1.2  is  1.3140478726
# Loss with C= 10  and epsilon=  1.4  is  1.31396504952
# Loss with C= 10  and epsilon=  1.6  is  1.31396400787
# Loss with C= 10  and epsilon=  1.8  is  1.31404679779
# Loss with C= 100  and epsilon=  0.0  is  1.3138788714
# Loss with C= 100  and epsilon=  0.2  is  1.31381137236
# Loss with C= 100  and epsilon=  0.4  is  1.31372770909
# Loss with C= 100  and epsilon=  0.6  is  1.31372185472
# Loss with C= 100  and epsilon=  0.8  is  1.3138053337
# Loss with C= 100  and epsilon=  1.0  is  1.31387815989
# Loss with C= 100  and epsilon=  1.2  is  1.31380445595
# Loss with C= 100  and epsilon=  1.4  is  1.3137210039
# Loss with C= 100  and epsilon=  1.6  is  1.31371052654
# Loss with C= 100  and epsilon=  1.8  is  1.31379364704
# Loss with C= 1000  and epsilon=  0.0  is  1.31134156019
# Loss with C= 1000  and epsilon=  0.2  is  1.31137164976
# Loss with C= 1000  and epsilon=  0.4  is  1.31135519621
# Loss with C= 1000  and epsilon=  0.6  is  1.31133827154
# Loss with C= 1000  and epsilon=  0.8  is  1.31130892996
# Loss with C= 1000  and epsilon=  1.0  is  1.31133422649
# Loss with C= 1000  and epsilon=  1.2  is  1.31132826552
# Loss with C= 1000  and epsilon=  1.4  is  1.31135582688
# Loss with C= 1000  and epsilon=  1.6  is  1.31127649758
# Loss with C= 1000  and epsilon=  1.8  is  1.31125785496
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-dd85d1daa655> in <module>()
#     105
#     106
# --> 107 crossValidate()
#     108
#
# <ipython-input-9-dd85d1daa655> in crossValidate()
#     101                         testSubset4[:,i]=testSubset4[:,i]/max(testSubset4[:,i])
#     102                 #rf3.fit(trainSubset3,trainLabels3)change here to program new function to train
# --> 103                 TrainFucntion(trainSubset3,trainLabels3,testSubset4,testLabels4)
#     104
#     105
#
# <ipython-input-9-dd85d1daa655> in TrainFucntion(x, y, xtest, ytest)
#      43
#      44     fig = plt.figure()
# ---> 45     ax=fig.add_subplot(111,projection='3d')
#      46     ax.scatter(plotx,ploty,accuracies)
#      47     plt.title('Loss of SVR with C and epsilon')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /usr/lib/pymodules/python2.7/mpl_toolkits/mplot3d/axes3d.pyc in __init__(self, fig, rect, *args, **kwargs)
#      89         Axes.__init__(self, fig, rect,
#      90                       frameon=True,
# ---> 91                       *args, **kwargs)
#      92         # Disable drawing of axes by base class
#      93         Axes.set_axis_off(self)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     518         self._hold = rcParams['axes.hold']
#     519         self._connected = {}  # a dict from events to (id, func)
# --> 520         self.cla()
#     521         # funcs used to format x and y - fall back on major formatters
#     522         self.fmt_xdata = None
#
# /usr/lib/pymodules/python2.7/mpl_toolkits/mplot3d/axes3d.pyc in cla(self)
#    1043         self._zmargin = 0
#    1044
# -> 1045         Axes.cla(self)
#    1046
#    1047         self.grid(rcParams['axes3d.grid'])
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in cla(self)
#    1002         self.containers = []
#    1003
# -> 1004         self.grid(False)  # Disable grid on init to use rcParameter
#    1005         self.grid(self._gridOn, which=rcParams['axes.grid.which'],
#    1006                     axis=rcParams['axes.grid.axis'])
#
# /usr/lib/pymodules/python2.7/mpl_toolkits/mplot3d/axes3d.pyc in grid(self, b, **kwargs)
#    1254         if len(kwargs) :
#    1255             b = True
# -> 1256         self._draw_grid = maxes._string_to_bool(b)
#    1257
#    1258     def ticklabel_format(self, **kwargs) :
#
# AttributeError: 'module' object has no attribute '_string_to_bool'
